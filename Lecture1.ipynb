# %% [markdown]
# # The computer security problem
# <pre>
#     • Buggy software
#     • Social Engineering
#     • Exploit vulnerabilities
# </pre>

# %% [markdown]
# ## Vul apps being exploited

# %%
from IPython.display import Image
Image(filename='src/1.png')

# %% [markdown]
# ## Client machines:
# <pre>
#     • IP address & bandwith stealing: Spam, DoS, Click fraud
#     • User credentials, crypto miners
#     • Ransomeware (Wannacry SMB Port 445)
# </pre>

# %% [markdown]
# ### User attacked stats

# %%
Image(filename='src/2.png')

# %% [markdown]
# ### Types of data stolen

# %%
Image(filename='src/3.png')

# %% [markdown]
# ### Vuls report market

# %%
Image(filename='src/4.png')
